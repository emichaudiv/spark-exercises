# %%
import pyspark
from pyspark.sql import functions as F

# %%
spark = pyspark.sql.SparkSession.builder.getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/05/19 09:20:41 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://edwards-air:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pandas as pd
import numpy as np

# %%
lan_dataframe = pd.DataFrame(dict(language=('python','SQL','Tableau')))
lan_dataframe
# Out:
#   language
# 0   python
# 1      SQL
# 2  Tableau

# %%
df = spark.createDataFrame(lan_dataframe)

# %%
df
# Out:
# DataFrame[language: string]

# %%
df.show()
# Out:
# +--------+
# |language|
# +--------+
# |  python|
# |     SQL|
# | Tableau|
# +--------+

# %%
df.printSchema()
# Out:
# root
#  |-- language: string (nullable = true)

# %%
df.count()
# Out:
# 3

# %%
from pydataset import data
mpg = data('mpg')

# %%
mpgdf = spark.createDataFrame(data('mpg'))

# %%
mpgdf.describe().show()
# Out:
# [Stage 22:>                                                         (0 + 8) / 8]
# +-------+------------+-----------------+------------------+-----------------+-----------------+----------+---+------------------+-----------------+----+-------+
# |summary|manufacturer|            model|             displ|             year|              cyl|     trans|drv|               cty|              hwy|  fl|  class|
# +-------+------------+-----------------+------------------+-----------------+-----------------+----------+---+------------------+-----------------+----+-------+
# |  count|         234|              234|               234|              234|              234|       234|234|               234|              234| 234|    234|
# |   mean|        null|             null| 3.471794871794872|           2003.5|5.888888888888889|      null|4.0|16.858974358974358|23.44017094017094|null|   null|
# ...

# %%
mpgdf.select(
    'statement',
    F.concat(
        F.lit('The '),
        mpg.year,
        F.lit(' '),
        mpg.manufacturer,
        F.lit(' '),
        mpg.model,
        F.lit(' has a'),
        mpg.cyl,
        F.lit(' cylinder engine')
        
    )
).select('statement').shoe(5,turncate=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
#       1 mpgdf.select(
#       2     'statement',
# ----> 3     F.concat(
#       4         F.lit('The '),
#       5         mpg.year,
#       6         F.lit(' '),
#       7         mpg.manufacturer,
#       8         F.lit(' '),
#       9         mpg.model,
#      10         F.lit(' has a'),
#      11         mpg.cyl,
#      12         F.lit(' cylinder engine')
#      13
#      14     )
#      15 ).select('statement').shoe(5,turncate=False)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pyspark/sql/utils.py:159, in try_remote_functions.<locals>.wrapped(*args, **kwargs)
#     157     return getattr(functions, f.__name__)(*args, **kwargs)
#     158 else:
# --> 159     return f(*args, **kwargs)
#
# ...

# %%
mpgdf.withColumn(
    'statement',
    F.concat(
        F.lit('The '),
        mpg.year,
        F.lit(' '),
        mpg.manufacturer,
        F.lit(' '),
        mpg.model,
        F.lit(' has a'),
        mpg.cyl,
        F.lit(' cylinder engine')
        
    )
).select('statement').shoe(5,turncate=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [94], in <cell line: 1>()
#       1 mpgdf.withColumn(
#       2     'statement',
# ----> 3     F.concat(
#       4         F.lit('The '),
#       5         mpg.year,
#       6         F.lit(' '),
#       7         mpg.manufacturer,
#       8         F.lit(' '),
#       9         mpg.model,
#      10         F.lit(' has a'),
#      11         mpg.cyl,
#      12         F.lit(' cylinder engine')
#      13
#      14     )
#      15 ).select('statement').shoe(5,turncate=False)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pyspark/sql/utils.py:159, in try_remote_functions.<locals>.wrapped(*args, **kwargs)
#     157     return getattr(functions, f.__name__)(*args, **kwargs)
#     158 else:
# --> 159     return f(*args, **kwargs)
#
# ...

# %%
mpgdf.select(
    F.when(
        mpg.trans.startswith('auto'),'auto'
    ).otherwise('manual')
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [95], in <cell line: 1>()
#       1 mpgdf.select(
#       2     F.when(
# ----> 3         mpg.trans.startswith('auto'),'auto'
#       4     ).otherwise('manual')
#       5 )
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'startswith'

# %%
from pydataset import data
tips = data('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       16.99  1.01  Female     No  Sun  Dinner     2
# 2       10.34  1.66    Male     No  Sun  Dinner     3
# 3       21.01  3.50    Male     No  Sun  Dinner     3
# 4       23.68  3.31    Male     No  Sun  Dinner     2
# 5       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tipdf = spark.createDataFrame(data('tips'))

# %%
tipdf.describe().show()
# Out:
# [Stage 25:>                                                         (0 + 8) / 8]
# +-------+------------------+------------------+------+------+----+------+------------------+
# |summary|        total_bill|               tip|   sex|smoker| day|  time|              size|
# +-------+------------------+------------------+------+------+----+------+------------------+
# |  count|               244|               244|   244|   244| 244|   244|               244|
# |   mean|19.785942622950813|2.9982786885245907|  null|  null|null|  null| 2.569672131147541|
# | stddev| 8.902411954856856| 1.383638189001182|  null|  null|null|  null|0.9510998047322344|
# |    min|              3.07|               1.0|Female|    No| Fri|Dinner|                 1|
# |    max|             50.81|              10.0|  Male|   Yes|Thur| Lunch|                 6|
# +-------+------------------+------------------+------+------+----+------+------------------+

# %%
(tipdf.filter(tipdf.smoker=='Yes').count()/tipdf.count())*100
# Out:
# 38.114754098360656

# %%
(tipdf.filter(tipdf.smoker=='No').count()/tipdf.count())*100
# Out:
# 61.885245901639344

# %%
tipdf.groupby(tipdf.smoker).agg(
F.round((F.count('time')/tipdf.count()),2).alias('perc')).show()
# Out:
# [Stage 46:=======>                                                  (1 + 7) / 8]
# +------+----+
# |smoker|perc|
# +------+----+
# |    No|0.62|
# |   Yes|0.38|
# +------+----+

# %%
tipdf.withColumn(
    'tip_perc',
    F.round((tipdf.tip/tips.total_bill)*100,2)
).select('tip','total_bill','tip_perc')
# Out:
# ---------------------------------------------------------------------------
# SparkRuntimeException                     Traceback (most recent call last)
# Input In [105], in <cell line: 1>()
#       1 tipdf.withColumn(
#       2     'tip_perc',
# ----> 3     F.round((tipdf.tip/tips.total_bill)*100,2)
#       4 ).select('tip','total_bill','tip_perc')
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pyspark/sql/column.py:161, in _bin_op.<locals>._(self, other)
#     156 def _(
#     157     self: "Column",
#     158     other: Union["Column", "LiteralType", "DecimalLiteral", "DateTimeLiteral"],
#     159 ) -> "Column":
#     160     jc = other._jc if isinstance(other, Column) else other
# --> 161     njc = getattr(self._jc, name)(jc)
#     162     return Column(njc)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
# ...

# %%
tipdf.withColumn(
    'tip_perc',
    F.round((tipdf.tip/tips.total_bill)*100,2)
).groupby('sex','smoker').agg(
    F.round(F.mean('tip_perc'),2)).alias('avg_perc').show()
# Out:
# ---------------------------------------------------------------------------
# SparkRuntimeException                     Traceback (most recent call last)
# Input In [107], in <cell line: 1>()
#       1 tipdf.withColumn(
#       2     'tip_perc',
# ----> 3     F.round((tipdf.tip/tips.total_bill)*100,2)
#       4 ).groupby('sex','smoker').agg(
#       5     F.round(F.mean('tip_perc'),2)).alias('avg_perc').show()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pyspark/sql/column.py:161, in _bin_op.<locals>._(self, other)
#     156 def _(
#     157     self: "Column",
#     158     other: Union["Column", "LiteralType", "DecimalLiteral", "DateTimeLiteral"],
#     159 ) -> "Column":
#     160     jc = other._jc if isinstance(other, Column) else other
# --> 161     njc = getattr(self._jc, name)(jc)
#     162     return Column(njc)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
# ...

# %%
from vega_datasets import data

# %%
weather = data.seattle_weather()

# %%
weather = spark.createDataFrame(weather)

# %%
weather.show(5)
# Out:
# +-------------------+-------------+--------+--------+----+-------+
# |               date|precipitation|temp_max|temp_min|wind|weather|
# +-------------------+-------------+--------+--------+----+-------+
# |2012-01-01 00:00:00|          0.0|    12.8|     5.0| 4.7|drizzle|
# |2012-01-02 00:00:00|         10.9|    10.6|     2.8| 4.5|   rain|
# |2012-01-03 00:00:00|          0.8|    11.7|     7.2| 2.3|   rain|
# |2012-01-04 00:00:00|         20.3|    12.2|     5.6| 4.7|   rain|
# |2012-01-05 00:00:00|          1.3|     8.9|     2.8| 6.1|   rain|
# +-------------------+-------------+--------+--------+----+-------+
# only showing top 5 rows

# %%
weather.withColumn('temp_min_F',
                   weather.temp_min * (9/5)+32
).show(2)
# Out:
# +-------------------+-------------+--------+--------+----+-------+----------+
# |               date|precipitation|temp_max|temp_min|wind|weather|temp_min_F|
# +-------------------+-------------+--------+--------+----+-------+----------+
# |2012-01-01 00:00:00|          0.0|    12.8|     5.0| 4.7|drizzle|      41.0|
# |2012-01-02 00:00:00|         10.9|    10.6|     2.8| 4.5|   rain|     37.04|
# +-------------------+-------------+--------+--------+----+-------+----------+
# only showing top 2 rows

# %%
weather.groupby('weather').sum('precipitation').show()
# Out:
# +-------+------------------+
# |weather|sum(precipitation)|
# +-------+------------------+
# |drizzle|               1.0|
# |   rain|1321.8000000000006|
# |    sun|239.39999999999995|
# |   snow|             208.1|
# |    fog|2655.7000000000003|
# +-------+------------------+

# %%
weather.groupby('weather').sum('wind').show()
# Out:
# +-------+------------------+
# |weather|         sum(wind)|
# +-------+------------------+
# |drizzle|             130.7|
# |   rain| 950.9999999999998|
# |    sun|2135.4999999999995|
# |   snow|             101.1|
# |    fog|            1417.0|
# +-------+------------------+

# %%
weather.withColumn(
    'year',
    F.year(weather.date)
).groupby(
'year'
).agg(
(F.mean('wind')).alias('mean_wind'),
    (F.mean('wind')).alias('total_wind')
).sort(F.col('mean_wind').desc()).first()
# Out:
# Row(year=2012, mean_wind=3.400819672131148, total_wind=3.400819672131148)

# %%
weather.filter(F.month(weather.date==1)).groupby('weather').count()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Input In [124], in <cell line: 1>()
# ----> 1 weather.filter(F.month(weather.date==1)).groupby('weather').count()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pyspark/sql/dataframe.py:3138, in DataFrame.filter(self, condition)
#    3136     jdf = self._jdf.filter(condition)
#    3137 elif isinstance(condition, Column):
# -> 3138     jdf = self._jdf.filter(condition._jc)
#    3139 else:
#    3140     raise PySparkTypeError(
#    3141         error_class="NOT_COLUMN_OR_STR",
#    3142         message_parameters={"arg_name": "condition", "arg_type": type(condition).__name__},
#    3143     )
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
# ...

# %%
weather.filter(
F.month(weather.date)==7).filter(F.year(weather.date)>2012).filter((F.year.date)<2015).agg(F.mean(temp_min.show()))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Input In [126], in <cell line: 1>()
#       1 weather.filter(
# ----> 2 F.month(weather.date)==7).filter(F.year(weather.date)>2012).filter((F.year.date)<2015).agg(F.mean(temp_min.show()))
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pyspark/sql/dataframe.py:2980, in DataFrame.__getattr__(self, name)
#    2976 if name not in self.columns:
#    2977     raise AttributeError(
#    2978         "'%s' object has no attribute '%s'" % (self.__class__.__name__, name)
#    2979     )
# -> 2980 jc = self._jdf.apply(name)
#    2981 return Column(jc)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
# ...

# %%
weather.filter((F.quarter(weather.date)==3).filter(F.year(weather.date)==2015)).select(F.when(weather.weather=='rain',1).otherwise(0)).mean().show()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Input In [128], in <cell line: 1>()
# ----> 1 weather.filter((F.quarter(weather.date)==3).filter(F.year(weather.date)==2015)).select(F.when(weather.weather=='rain',1).otherwise(0)).mean().show()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pyspark/sql/dataframe.py:2980, in DataFrame.__getattr__(self, name)
#    2976 if name not in self.columns:
#    2977     raise AttributeError(
#    2978         "'%s' object has no attribute '%s'" % (self.__class__.__name__, name)
#    2979     )
# -> 2980 jc = self._jdf.apply(name)
#    2981 return Column(jc)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
# ...

# %%
weather.withColumn('year',F.year(weather.date)).withColumn('has_rained',weather.percipitation>0).show()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Input In [129], in <cell line: 1>()
# ----> 1 weather.withColumn('year',F.year(weather.date)).withColumn('has_rained',weather.percipitation>0).show()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pyspark/sql/dataframe.py:2980, in DataFrame.__getattr__(self, name)
#    2976 if name not in self.columns:
#    2977     raise AttributeError(
#    2978         "'%s' object has no attribute '%s'" % (self.__class__.__name__, name)
#    2979     )
# -> 2980 jc = self._jdf.apply(name)
#    2981 return Column(jc)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
# ...
